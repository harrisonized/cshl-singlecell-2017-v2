# %% [markdown]
# This notebook loosely follows 02_make_celltype_metadata.ipynb
#
# Input: Data was hard-coded from [Figure 5D](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4481139/figure/F5/) of the paper.
#
# Output: cluster_ids_to_celltypes.csv
#
# Because of the way I hardcoded the small dataset, no need to save.

# %%
from functions.data import ClusterToCellType

# %%
to_save=False

# %% [markdown]
# # Get Data

# %%
cluster_to_celltype = ClusterToCellType()
cluster_to_celltype.dataframe
# Out:
#    cluster_no               cell_type cluster_name
# 0           1        Horizontal cells   cluster_01
# 1           2  Retinal ganglion cells   cluster_02
# 2           3          Amacrine cells   cluster_03
# 3           4          Amacrine cells   cluster_04
# 4           5          Amacrine cells   cluster_05
# 5           6          Amacrine cells   cluster_06
# 6           7          Amacrine cells   cluster_07
# 7           8          Amacrine cells   cluster_08
# 8           9          Amacrine cells   cluster_09
# 9          10          Amacrine cells   cluster_10
# 10         11          Amacrine cells   cluster_11
# 11         12          Amacrine cells   cluster_12
# 12         13          Amacrine cells   cluster_13
# 13         14          Amacrine cells   cluster_14
# 14         15          Amacrine cells   cluster_15
# 15         16          Amacrine cells   cluster_16
# 16         17          Amacrine cells   cluster_17
# ...

# %%
if to_save:
    cluster_to_celltype.dataframe.to_csv(f'data/cluster_ids_to_celltypes.csv', index=False)
